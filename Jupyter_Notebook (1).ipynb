# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Inés Sabaté Ferrer**
# Applied intelligence consultant

# %% [markdown]
# *My interest in data science is increasingly growing as I am taking this course. I am interested in the fact the use of data can improve processes in every existing field, and I think knowing the tools and the techniques to apply such technology is a great opportunity for a young student.

# %% [markdown]
# ### The code will return the value of the value assigned to "a" in the first row of the code.

# %%
a=1000
print(a)

# %% [markdown]
# - January
# - February
# - March
# - April
#
# >Blockquotes can hold the large chunk of text and are generally indented. They can be obtained by using Markdown symbol ">" that appears at the beginning of the text.
